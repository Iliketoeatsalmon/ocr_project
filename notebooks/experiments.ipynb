# %% [markdown]
# # OCR Experiments\n\nUse this notebook for manual experimentation on:\n- ROI coordinate calibration\n- Preprocessing parameter tuning\n- OCR backend behavior and confidence quality\n
